# %% [markdown]
# # Import Libraries

# %%
# !git clone https://github.com/dknayakbu/ERA-V1-Assignments.git
# !git -C ERA-V1-Assignments pull
# !pip install --quiet "pandas" "torch" "torchtext" "torchvision" "ipython[notebook]" "seaborn" "pytorch-lightning" "torchmetrics" "lightning-bolts" "torch-lr-finder" "grad-cam" "gradio" "torchinfo" "tokenizers" "datasets" "torchsummary"
# Out:
# Cloning into 'ERA-V1-Assignments'...
# remote: Enumerating objects: 361, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 361 (delta 79), reused 136 (delta 41), pack-reused 180
# Receiving objects: 100% (361/361), 103.70 MiB | 21.57 MiB/s, done.
# Resolving deltas: 100% (154/154), done.
# Already up to date.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.0/727.0 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.4/763.4 kB 15.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 45.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 80.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 99.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 45.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 38.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.2/298.2 kB 33.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 887.1 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.4 MB/s eta 0:00:00
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Building wheel for ffmpy (setup.py) ... done

# %%
import sys
sys.path.append("ERA-V1-Assignments/S16")

# %%
from config import get_config
cfg = get_config()
cfg['batch_size'] = 16
cfg['preload'] = None
cfg['num_epochs'] = 10

from train import train_model

train_model(cfg)
# Out:
# Using device: cuda
# Downloading builder script:   0%|          | 0.00/6.08k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/161k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/20.5k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/127085 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/127085 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/126792 [00:00<?, ? examples/s]
# Max length of source sentence: 149
# Max length of target sentence: 159
# Building transformer...
# InputEmbeddings
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# building positional encoding
# building encoder_blocks
# building decoder_blocks
# Build Encoder and Decoder
# Build projection_layer
# Build transformer
# Processing Epoch 00: 100%|██████████| 6641/6641 [1:31:19<00:00,  1.21it/s, loss=5.010]
# --------------------------------------------------------------------------------
#     SOURCE: "As to that," said Étienne, "if you like, they'll take your certificate back to-morrow.
#     TARGET: —Laisse donc! dit Étienne. Si tu veux, ils te le reprendront demain, ton livret.
#  PREDICTED: -- Comme , dit Étienne , vous êtes comme vous , comme vous allez faire votre tour .
# --------------------------------------------------------------------------------
#     SOURCE: Never had these gatherings been so gay and noisy.
#     TARGET: Jamais les réceptions n'avaient été si gaies, ni si bruyantes.
#  PREDICTED: Jamais ces gens avaient été et de la .
# --------------------------------------------------------------------------------
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `CharErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `CharErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `WordErrorRate` from `torchmetrics` was deprecated and will be removed in 2.0. Import `WordErrorRate` from `torchmetrics.text` instead.
#   _future_warning(
# /usr/local/lib/python3.10/dist-packages/torchmetrics/utilities/prints.py:62: FutureWarning: Importing `BLEUScore` from `torchmetrics` was deprecated and will be removed in 2.0. Import `BLEUScore` from `torchmetrics.text` instead.
#   _future_warning(
# Processing Epoch 01: 100%|██████████| 6641/6641 [1:31:18<00:00,  1.21it/s, loss=4.198]
# --------------------------------------------------------------------------------
#     SOURCE: The wind was still strong, but fortunately it did not rain.
#     TARGET: Le vent était toujours violent, mais heureusement il ne pleuvait plus.
#  PREDICTED: Le vent était encore plus fort , mais heureusement , il n ' y avait pas une pluie .
# --------------------------------------------------------------------------------
#     SOURCE: The dragoon and the Swiss followed him, and all their comrades followed the dragoon and the Swiss.
#     TARGET: Le dragon et le Suisse l'avaient suivi, tous les camarades avaient suivi le dragon et le Suisse.
#  PREDICTED: Le dugong et le le suivit , et tous les camarades le hangar et le .
# --------------------------------------------------------------------------------
# Processing Epoch 02:  50%|█████     | 3330/6641 [45:50<45:26,  1.21it/s, loss=3.553]
